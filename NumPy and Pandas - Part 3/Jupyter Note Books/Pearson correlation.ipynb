# %%
import pandas as pd
import numpy as np

# %%
filename = 'nyc_subway_weather.csv'
subway_df = pd.read_csv(filename)

# %%
subway_df.head()
# Out:
#    UNIT     DATEn     TIMEn  ENTRIESn   EXITSn  ENTRIESn_hourly  \
# 0  R003  5/1/2011   0:00:00   4388333  2911002                0
# 1  R003  5/1/2011   4:00:00   4388333  2911002                0
# 2  R003  5/1/2011  12:00:00   4388333  2911002                0
# 3  R003  5/1/2011  16:00:00   4388333  2911002                0
# 4  R003  5/1/2011  20:00:00   4388333  2911002                0
#
#    EXITSn_hourly        datetime  hour  day_week  ...  pressurei rain  tempi  \
# 0              0   5/1/2011 0:00     0         6  ...      30.22    0   55.9
# 1              0   5/1/2011 4:00     4         6  ...      30.25    0   52.0
# 2              0  5/1/2011 12:00    12         6  ...      30.28    0   62.1
# 3              0  5/1/2011 16:00    16         6  ...      30.26    0   57.9
# 4              0  5/1/2011 20:00    20         6  ...      30.28    0   52.0
#
#    wspdi meanprecipi  meanpressurei  meantempi  meanwspdi  weather_lat  \
# ...

# %%
def correlation(x, y):
# Out:
#   File "<ipython-input-4-c1b6573e8415>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing
